# %%
import pandas as pd

# %%
df = df1 = pd.read_csv('RBC_corpus_for_annotations.csv')

# %%
df.tail()
# Out:
#         Unnamed: 0                                               Text  \
# 4178  ############                                                NaN
# 4179          2181  Полиция задержала подозреваемого в организации...
# 4180  ############                                                NaN
# 4181          2182  Останкинский суд Москвы приговорил гадалку Нон...
# 4182  ############                                                NaN
#
#                                                   Title  \
# 4178                                                NaN
# 4179  Подозреваемого в хищении банковских активов на...
# 4180                                                NaN
# 4181  Суд приговорил гадалку из дела Нота-банка к 3,...
# 4182                                                NaN
#
#                             id
# 4178                       NaN
# 4179  5c8b840b9a79475bf3d3a61c
# 4180                       NaN
# 4181  5c8f650d9a7947b6bdc51ac6
# 4182                       NaN

# %%
df1 = df.dropna()

# %%
df1.head()
# Out:
#   Unnamed: 0                                               Text  \
# 1          0  Федеральное налоговое ведомство США по итогам ...
# 3          1  Приволжское следственное управление на транспо...
# 5          2  Уголовное дело , фигурантом которого был генер...
# 7          3  Московская налоговая инспекция проводит новую ...
# 9          4  Российское следствие объявило украинского бизн...
#
#                                                Title                        id
# 1  Компанию Coca-Cola обвинили в неуплате налогов...  55fcbbcf9a7947804181c2bc
# 3  Два уголовных дела возбуждены по факту неуплат...  56c1b3049a79477d0605a808
# 5  Уголовное дело против главы СУ-155 прекратили ...  56c5aec19a79479c62a688fc
# 7  СМИ сообщили о новой проверке о неуплате налог...  56c68ab19a79475ef96ee710
# 9  Украинского бизнесмена объявили в розыск из-за...  570e606f9a7947b8ace4ae94

# %%
df['Text'][2683]
# Out:
# nan

# %%
l = []
for i in range(1437*2+1, 1442*2+1):
    if i%2==1 and i!=2095 and i!=2263 and i!=2683:
        print(i)
        string = '\n############\n' +str(i)+','+ df['Text'][i] +','+ df['Title'][i] + ',' +df['id'][i]
        l.append(string)
l
# Out:
# 2875
# 2877
# 2879
# 2881
# 2883
# ...
