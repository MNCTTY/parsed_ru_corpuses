# %% [markdown]
# # 1

# %%
clause_dict = {
            
            "СТАТЬЯ 3. ДОГОВОРНАЯ ЦЕНА ( п.п. 3.1 _3.20)":
            [
                "договор[\w]* цен[\w]*",
                "формир[\w]* наряд-заказ[\w]*",
                "общ[\w]* сумм[\w]* всех наряд-заказ[\w]*",
                "общ[\w]* сумм[\w]* наряд-заказ[\w]*",
                "превыш[\w]* договорн[\w]* цен[\w]*",
                "превыш[\w]* цен[\w]* договор[\w]*",
                "стоим[\w]* работ[\w]* наряд-заказ[\w]*",
                "стоимост[\w]* задан[\w]*",
                "стоимост[\w]* работ[\w]*",
                "стоимост[\w]* наряд-заказ[\w]*",
                "стоимост[\w]* договор[\w]*",
                "стоимост[\w]* поставк[\w]*",
                "работ[\w]* по наряд-заказ[\w]*",
                "возмещен[\w]* работ[\w]*",
                "затрат[\w]*",
                "не более стоимост[\w]* работ[\w]*",
                "не менее стоимост[\w]* работ[\w]*",
                "прейскурант[\w]*",
                "став[\w]* [\w]*ценок[\w]*",
                "един[\w]* [\w]*цен[\w]*",
                "уер"
            ],





            "СТАТЬЯ 5. ПОРЯДОК И УСЛОВИЯ ПЛАТЕЖЕЙ ( п.п. 5.1 _5.20)":
            [
                "[\w]*плат[\w]* выполн[\w]* по договор[\w]* работ[\w]*",
                "график[\w]* финанс[\w]*",
                "подтвержд[\w]* строител[\w]* контрол[\w]*",
                "акт[\w]* о прием[\w]* выполн[\w]* работ[\w]*",
                "[\w]*гаш[\w]* аванс[\w]*",
                "[\w]*гаc[\w]* аванс[\w]*",
                "аванс[\w]*",
                "окончательн[\w]* платеж[\w]*",
                "послед[\w]* платеж[\w]*",
                "платеж[\w]* по договор[\w]*",
                "аванс[\w]* в размер[\w]*",
                "в том числе ндс",
                "цел[\w]* аванс[\w]*",
                "акт[\w]* свер[\w]*",
                "взаиморасчет[\w]* по договор[\w]*",
                "нецел[\w]* аванс[\w]*",
                "измен[\w]* реквизит[\w]*",
                "взаимн[\w]* расчет[\w]*",
                "использ[\w]* аванс[\w]* средст[\w]*",
                "перечисл[\w]* аванс[\w]*",
                "возвр[\w]* аванс[\w]*"
            ],




            "СТАТЬЯ 7. ЗАВЕРЕНИЯ ОБ ОБСТОЯТЕЛЬСТВАХ, ИМЕЮЩИХ ЗНАЧЕНИЕ ДЛЯ ЗАКЛЮЧЕНИЯ, ИСПОЛНЕНИЯ ИЛИ ПРЕКРАЩЕНИЯ ДОГОВОРА ( п.п. 7.1 _7.9)":
            [
                "переч[\w]* нарушен[\w]*",
                "штраф[\w]* санкц[\w]*",
                "договор[\w]* примен[\w]*",
                "наруш[\w]* в област[\w]*",
                "информац[\w]* безопас[\w]*",
                "ппэб",
                "охран[\w]* труд[\w]*",
                "наруш[\w]* подрядчик[\w]* услов[\w]*",
                "односторон[\w]* отказ[\w]*",
                "отказ[\w]* от исполн[\w]*",
                "возмещ[\w]* подрядчик[\w]* стоимост[\w]*",
                "стоимост[\w]* фактическ[\w]* выполн[\w]*",
                "повлек[\w]* смерт[\w]*"
            ],




            "СТАТЬЯ 9. ОБЯЗАТЕЛЬСТВА ЗАКАЗЧИКА  ( п.п. 9.1 _9.15)":
            [
                "оплат[\w]* выполн[\w]* подрядчик[\w]* работ[\w]*",
                "оплат[\w]* выполн[\w]* работ[\w]*",
                "обеспеч[\w]* получен[\w]*",
                "перед[\w]* подрядчик[\w]*",
                "необходим[\w]* документ[\w]*",
                "согласован[\w]*",
                "разрешен[\w]*",
                "проект[\w]* документ[\w]*",
                "рабоч[\w]* документ[\w]*",
                "производств[\w]* работ[\w]*",
                "прием[\w]*-передач[\w]* строител[\w]* площад[\w]*",
                "после подписан[\w]*",
                "подписан[\w]* наряд-заказ[\w]*",
                "проведен[\w]* строител[\w]* контрол[\w]*",
                "автор[\w]* надзор[\w]*",
                "контрол[\w]* за производств[\w]*",
                "работ[\w]* на объект[\w]*",
                "поставк[\w]* материал[\w]*",
                "поставк[\w]* оборуд[\w]*",
                "наруш[\w]* договор[\w]* обязательств[\w]* заказчик[\w]*",
                "наруш[\w]* договор[\w]* обязательств[\w]*",
                "наруш[\w]* срок[\w]* [\w]*плат[\w]*"
            ],




            "СТАТЬЯ 11. РИСКИ СЛУЧАЙНОЙ ГИБЕЛИ ИЛИ ПОВРЕЖДЕНИЯ ОБЪЕКТА  ( п.п. 11.1 _11.1)":
            [
                "прием[\w]* законч[\w]* строит[\w]*",
                "риск[\w]* случай[\w]*",
                "случай[\w]* гибел[\w]*",
                "случай[\w]* поврежд[\w]*",
                "обязан[\w]* по обеспеч[\w]* сохран[\w]*",
                "обязан[\w]* по обеспеч[\w]* целост[\w]*",
                "сохран[\w]*",
                "целост[\w]*"
            ],




            "СТАТЬЯ 13. ОБЩИЕ УСЛОВИЯ ПРОИЗВОДСТВА РАБОТ. НАРЯД-ДОПУСКИ  ( п.п. 13.1 _13.4)":
            [
                "общ[\w]* журнал[\w]* работ[\w]*",
                "приступ[\w]* к выполн[\w]*",
                "письмен[\w]* разреш[\w]*",
                "выда[\w]* разреш[\w]*",
                "провер[\w]* производств[\w]* готов[\w]*",
                "работ[\w]* повыш[\w]* опас[\w]*",
                "взрыв[\w]* объект[\w]*",
                "пожар[\w]* объект[\w]*",
                "оформ[\w]* наряд[\w]*-допуск[\w]*",
                "правил[\w]* внутр[\w]* распоряд[\w]*",
                "график[\w]* выполн[\w]* работ[\w]*"
            ],




            "СТАТЬЯ 15. МОТИВАЦИЯ СОБЛЮДЕНИЯ ПОЛОЖЕНИЙ ДОГОВОРА В ОБЛАСТИ ПБ  ( п.п. 15.1 _15.18)":
            [
                "исполн[\w]* подрядчик[\w]* обязательств[\w]*",
                "обязательств[\w]* в област[\w]* пб",
                "производств[\w]* безопас[\w]*",
                "существ[\w]* услов[\w]*",
                "материал[\w]* поощр[\w]*",
                "поощр[\w]* за соблюд[\w]*",
                "соблюд[\w]* треб[\w]* заказчик[\w]*",
                "пэб[\w]* от",
                "пэб[\w]* от[\w]* и гз[\w]*",
                "поощр[\w]*",
                "ключ[\w]* показат[\w]* эффектив[\w]* в област[\w]* пб",
                "план[\w]* управ[\w]* договор[\w]* в област[\w]* пб",
                "план[\w]* управ[\w]* договор[\w]*",
                "оцен[\w]* лист[\w]* деятел[\w]*",
                "оцен[\w]* кпэ[\w]* пэб",
                "выпол[\w]* кпэ[\w]* пэб",
                "проактив[\w]*",
                "начисл[\w]* поощр[\w]*",
                "инцидент[\w]*",
                "травм[\w]* работник[\w]*",
                "смерт[\w]* работник[\w]*",
                "штраф[\w]* санкц[\w]*"
            ],




            "СТАТЬЯ 17. ПРИВЛЕЧЕНИЕ СУБПОДРЯДЧИКОВ  ( п.п. 17.1 _17.8)":
            [
                "привлеч[\w]* [\w]*подрядч[\w]*",
                "субподрядчик[\w]*",
                "письм[\w]* соглас[\w]* заказчик[\w]*",
                "переч[\w]* выполн[\w]* работ[\w]*",
                "замен[\w]* заявл[\w]*",
                "поставщик[\w]* мтр",
                "производител[\w]* мтр",
                "привлеч[\w]* нов[\w]*",
                "трет[\w]* лиц[\w]*",
                "трет[\w]* сторон[\w]*"
            ],




            "СТАТЬЯ 19. УСТРАНЕНИЕ ДЕФЕКТОВ/НЕДОСТАТКОВ  ( п.п. 19.1 _19.3)":
            [
                "дефект[\w]*",
                "недостат[\w]*",
                "не соответств[\w]*",
                "устран[\w]* обнаруж[\w]*",
                "устран[\w]* дефект[\w]*",
                "устран[\w]* недостат[\w]*",
                "срок[\w]* не мо[\w]* превы[\w]*",
                "гарант[\w]* срок[\w]*",
                "неполн[\w]*",
                "некомплект[\w]*",
                "за свой счет",
                "устран[\w]* все[\w]*",
                "устран[\w]* выявл[\w]*",
                "исправл[\w]* дефект[\w]*",
                "замен[\w]* дефект[\w]*",
                "доукомплект[\w]*"
            ],




            "СТАТЬЯ 21. ПРИЕМКА В ЭКСПЛУАТАЦИЮ ЗАКОНЧЕННОГО СТРОИТЕЛЬСТВОМ ОБЪЕКТА  ( п.п. 21.1 _21.5)":
            [

                 "приемк[\w]*",
                 "прием[\w]* комис[\w]*",
                 "акт[\w]* прием[\w]* закончен[\w]* строительст[\w]* объект[\w]* (КС-11)",
                 "акт[\w]* прием[\w]*"

            ],




            "СТАТЬЯ 23. УПРАВЛЕНИЕ ЭФФЕКТИВНОСТЬЮ ДЕЯТЕЛЬНОСТИ КОНТРАГЕНТОВ  ( п.п. 23.1 _23.5)":
            [

                "прилож[\w]* №8",
                "уэдк",
                "неспособ[\w]*"

            ],




            "СТАТЬЯ 27. УРЕГУЛИРОВАНИЕ СПОРОВ. АРБИТРАЖ  ( п.п. 27.1 _27.4)":
            [

                "претенз[\w]*",
                "мотивиров[\w]* ответ[\w]*",
                "отказ[\w]*"
            ],




            "СТАТЬЯ 29. СТРАХОВАНИЕ (п. 29.1. _29.11)":
            [

                "страх[\w]*",
                "страхов[\w]*"

            ],




            "СТАТЬЯ 31. РАБОЧАЯ ДОКУМЕНТАЦИЯ. ВНЕСЕНИЕ ИЗМЕНЕНИЙ В РАБОЧУЮ ДОКУМЕНТАЦИЮ   ( п.п. 31.1 _31.8)":
            [

                "рабоч[\w]* документац[\w]*",
                "изменен[\w]*",
                "документац[\w]*",

            ],

            "СТАТЬЯ 4. ПРИЕМКА ВЫПОЛНЕННЫХ РАБОТ. УЧЕТНАЯ ДОКУМЕНТАЦИЯ. ( п.п. 4.1 _4.20)":
            [
                "приемк[\w]*",
                 "приемк[\w]* выполнен[\w]*  работ[\w]* ",
                "приемк[\w]* выполнен[\w]*",
                "выполнен[\w]* затрат[\w]*", 
                 "выполнен[\w]* работ[\w]*",
                "журнал[\w]* работ[\w]*",
                "выполнен[\w]* ключев[\w]* событ[\w]*",
                "выполнен[\w]*",
                "выполнен[\w]* дополнительн[\w]* объем[\w]*",
                "принят[\w]*"
            ],

            "СТАТЬЯ 6. СРОКИ ДЕЙСТВИЯ ДОГОВОРА И СРОКИ ВЫПОЛНЕНИЯ РАБОТ ( п.п. 6.1 _6.8.7)":
            [
                "срок[\w]* выполнен[\w]*",
                "график[\w]* выполнен[\w]*",
                "Задерж[\w]* срок[\w]*",
                "продлен[\w]* срок[\w]*"
                "измен[\w]* сроко[\w]*",
                "планиров[\w]* работ[\w]*",
                "график[\w]*"
            ],

            "СТАТЬЯ 8. ОБЯЗАТЕЛЬСТВА ПОДРЯДЧИКА ( п.п. 8.1 _8.48)":
            [
                "соглас[\w]* с заказч[\w]*",
                "перед[\w]* заказч[\w]*",
                "нач[\w]* производств[\w]* строительно-монтажных работ[\w]*",
                "акт[\w]*-допуск[\w]*", 
                "акт[\w]* передач[\w]*",
                "соглас[\w]* с орган[\w]* местн[\w]* самоуправл[\w]*",
                 "владел[\w]* дорог[\w]*",
                 "транспорт[\w]* схем[\w]*",

                "обеспеч[\w]* своевремен[\w]*",
                "приостанов[\w]* работ[\w]* до",
                "письменно предупре[\w]*",
                "согласов[\w]*",
                "отзыв[\w]*",
                "отозв[\w]*",
                "исполн[\w]*",
                "соглас[\w]*"
            ],

            "СТАТЬЯ 10. ПОСТАВКА МАТЕРИАЛОВ И ОБОРУДОВАНИЯ  ( п.п. 10.1 _10.23)":
            [
                "поставляем[\w]*  материал[\w]* ",
                 "поставляем[\w]*  оборудов[\w]*",
                "акт[\w]* испытан[\w]*",
                "порч[\w]* материал[\w]*", 
                "потер[\w]* материал[\w]*",
                "использов[\w]* материал[\w]*",
                "материальн[\w]*ценност[\w]*",
                "давальч[\w]* основ[\w]*",
                "давальч[\w]* материал[\w]*",
                "материа[\w]* и оборудов[\w]*",
                "утрач[\w]*",
                "отчет[\w]* по состоянию постав[\w]* материал[\w]* и оборудов[\w]*",
                "ведомост[\w]* постав[\w]* материал[\w]* и оборудов[\w]*" 
            ],

            "СТАТЬЯ 14. ТРЕБОВАНИЯ В ОБЛАСТИ ПРОМЫШЛЕННОЙ И ЭКОЛОГИЧЕСКОЙ БЕЗОПАСНОСТИ, ОХРАНЫ ТРУДА И ГРАЖДАНСКОЙ ЗАЩИТЫ (ПЭБ, ОТ и ГЗ) ПРИ ВЫПОЛНЕНИИ РАБОТ НА ОБЪЕКТАХ ЗАКАЗЧИКА   ( п.п. 14.1 _14.6)":
            [
                "требован[\w]* в област[\w]*", 
                "требован[\w]* в област[\w]* пэб, от и гз",
                "област[\w]* пэб, от и гз",
                "приложен[\w]* №13",
                "перечн[\w]* нарушен[\w]* и штрафн[\w]* санкц[\w]*",
                "нарушен[\w]* требован[\w]* в облас[\w]* пб",
                "нарушен[\w]*",
                "област[\w]* электробезопасн[\w]*",
                "основн[\w]* правил[\w]* безопас[\w]*",
                "приложен[\w]* №21 к соглаш[\w]* в област[\w]* пэб, от и гз"
            ],

            "СТАТЬЯ 16. ПЕРСОНАЛ ПОДРЯДЧИКА  ( п.п. 16.1 _16.11)":
            [
                "своевремен[\w]* выплат[\w]* заработ[\w]*плат[\w]*",
                 "своевремен[\w]* выплат[\w]* пособ[\w]*",
                 "пособ[\w]*",
                "заработ[\w]* плат[\w]*",
                "пропуск[\w]* для работ[\w]*",
                "пропуск[\w]* для транспорт[\w]*"
            ],

            "СТАТЬЯ 18. СКРЫТЫЕ РАБОТЫ  ( п.п. 18.1 _18.5)":
            [
                "акт[\w]* освидетельств[\w]* скрыт[\w]* работ[\w]*",
                "скрыт[\w]* работ[\w]*", 
                "акт[\w]* гидравлич[\w]*  испытан[\w]*", 
                "акт[\w]* пневматич[\w]* испытан[\w]*", 
                "лабор[\w]* исслед[\w]*"
            ],

            "СТАТЬЯ 20. КОНТРОЛЬ КАЧЕСТВА ВЫПОЛНЕНИЯ РАБОТ  ( п.п. 20.1 _20.7)":
            [
                "строител[\w]* контрол[\w]*",
                "входн[\w]* контрол[\w]*",
                "контрол[\w]*",
                "провер[\w]* и контрол[\w]* ход[\w]* и качеств[\w]*",
                "провер[\w]* ход[\w]*",
                "провер[\w]* качеств[\w]*",
                "контрол[\w]*ход[\w]*",
                "контрол[\w]* качеств[\w]*",
                "провер[\w]* ход[\w]* и качеств[\w]*",
                "контрол[\w]* ход[\w]* и качеств[\w]*",
                "качеств[\w]*",
                "квалиф[\w]*",
                "правильн[\w]* использ[\w]*"
            ],

            "СТАТЬЯ 22. ГАРАНТИЙНЫЙ СРОК.  ( п.п. 22.1 _22.11)":
            [
                "гарант[\w]* срок[\w]*",
                "акт[\w]* прием[\w]* закончен[\w]* строительств[\w]*",
                "Продолжитель[\w]* гарант[\w]* срок[\w]*",
                "сертификат[\w]*",
                "работ[\w]* по исправл[\w]* и устран[\w]* дефект[\w]*",
                "работ[\w]* по устран[\w]* дефект[\w]*",
                "работ[\w]* по исправл[\w]* дефект[\w]*",
                "замен[\w]* дефект[\w]*",
                "устран[\w]* недостат[\w]* дефект[\w]*",
                "устран[\w]* дефект[\w]*",
                "некачеств[\w]*",
                "гарант[\w]* экспл[\w]*"
            ],

            "СТАТЬЯ 24. ОТВЕТСТВЕННОСТЬ СТОРОН  ( п.п. 24.1 _24.36)":
            [
                "вправ[\w]* "
                "вправ[\w]* взыс[\w]*",
                "неуст[\w]*",
                "обязан",
                "вправе отказ[\w]*" ,
                "[\w]*требов[\w]*"
                "предъяв[\w]* [\w]*требов[\w]*",
                "наруш[\w]*",
                "неисполн[\w]* [\w]*требов[\w]*",
                "[\w]*штраф[\w]*",
                "убыт[\w]*",
                "причин[\w]* трет[\w]* лиц[\w]*",
                "ненадлежащ[\w]* исполнен[\w]*", 
                "несвоеврем[\w]* представл[\w]*" ,
                "санкц[\w]*",
                "прав[\w]*",
                "требов[\w]*",
                "претенз[\w]*",
                "взыск[\w]*"
            ],

            "СТАТЬЯ 26. ФОРС-МАЖОРНЫЕ ОБСТОЯТЕЛЬСТВА  ( п.п. 26.1 _26.7)":
            [
                "форс-мажор[\w]*",
                "заключен[\w]* Торгово-промышленной палат[\w]*"
            ],

            "СТАТЬЯ 28. РАСТОРЖЕНИЕ ДОГОВОРА И/ИЛИ НАРЯД-ЗАКАЗА  ( п.п. 28.1 _28.12)":
            [
                "растор[\w]*",
                "задерж[\w]* срок[\w]* начал[\w]*" ,
                "допус[\w]*",
                 "допус[\w]* наруш[\w]*",
                "банкрот[\w]*",
                "отказ[\w]* от исполн[\w]*",
                "односторон[\w]* отказ[\w]*",
                "полн[\w]* отказ[\w]*"
            ],

            "СТАТЬЯ 32. ПРОЧИЕ УСЛОВИЯ ( п.п. 32.1 _32.3)":
            [
                "резидент[\w]*", 
                "бенефициар[\w]*"
            ]



        }

# %%
import json

with open('clause_dict.json', 'w') as fp:
    json.dump(clause_dict, fp, sort_keys=True, indent=4)

# %%
with open('clause_dict.json', 'r') as fp:
    data = json.load(fp)

# %%
data==clause_dict
# Out:
# True

# %% [markdown]
# # 2

# %%
reg_quality_old = ["недостат", "неполн",  
            "качеств", "груб", "наруш", "допущен", "штраф", "несоответств", "устран", "удовлетвор", "замечан", "претенз" ]

# %%
with open('reg_quality_list.txt', 'w') as filehandle:
    for listitem in reg_quality_old:
        filehandle.write('%s\n' % listitem)

# %%
reg_quality = []

with open('reg_quality_list.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentPlace = line[:-1]

        reg_quality.append(currentPlace)

# %%
reg_quality == reg_quality_old
# Out:
# True

# %%
reg_durations_old = ["срок", "сроч", "врем", "график", "период", "течени", 
                "задерж", "поздн", "дате", "дата", "даты", "заверш", "начат", "начало", "начала", "начале", "начин", "законч"]

# %%
with open('reg_durations_list.txt', 'w') as filehandle:
    for listitem in reg_durations_old:
        filehandle.write('%s\n' % listitem)

# %%
reg_durations = []

with open('reg_durations_list.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentPlace = line[:-1]

        reg_durations.append(currentPlace)

# %%
reg_durations == reg_durations_old
# Out:
# True

# %%
reg_prices_old = ["аванс", "стоимост", "оплат", "платёж", "платеж",
        "цена", "цено",
        "руб\.", "рубл",
        "сумм",
        "финансир", "погашен",
        "расходы", "доходы",
        "расходн", "доходн",
        "расходах", "доходах",
        "расходов", "доходов",
        "расходам", "доходам",
        "перечисл", "счёт",
        "расчёт", "расчет", "счет",
        "неустой", "денег", "денеж",
        "нецелев", "взыск", "начисл",
        "поступл", "возврат", "растор", "трат", "трач",
        "договор[\w]* цен[\w]*",
        "стоимост[\w]* работ[\w]*",
        "общ[\w]* сумм[\w]* наряд-заказ[\w]*",
        "превыш[\w]* договорн[\w]* цен[\w]*",
        "превыш[\w]* цен[\w]* договор[\w]*",
        "стоим[\w]* работ[\w]* наряд-заказ[\w]*",
        "стоимост[\w]* задан[\w]*",
        "стоимост[\w]* наряд-заказ[\w]*",
        "стоимост[\w]* договор[\w]*",
        "стоимост[\w]* поставк[\w]*",
        "возмещен[\w]* работ[\w]*",
        "затрат[\w]*",
        "не более стоимост[\w]* работ[\w]*",
        "не менее стоимост[\w]* работ[\w]*",
        "прейскурант[\w]*",
        "став[\w]* [\w]*ценок[\w]*",
        "уер",
        "[\w]*плат[\w]* выполн[\w]* договор[\w]* работ[\w]* ",
        "график[\w]* финанс[\w]*",
        "[\w]*гаш[\w]* аванс[\w]*",
        "[\w]*гаc[\w]* аванс[\w]*",
        "окончательн[\w]* платеж[\w]*",
        "послед[\w]* платеж[\w]*",
        "акт[\w]* свер[\w]*",
        "взаиморасчет[\w]* по договор[\w]*",
        "нецел[\w]* аванс[\w]*",
        "измен[\w]* реквизит[\w]*",
        "взаимн[\w]* расчет[\w]*"]

# %%
with open('reg_prices_list.txt', 'w') as filehandle:
    for listitem in reg_prices_old:
        filehandle.write('%s\n' % listitem)

# %%
reg_prices = []

with open('reg_prices_list.txt', 'r') as filehandle:
    for line in filehandle:
        # remove linebreak which is the last character of the string
        currentPlace = line[:-1]

        reg_prices.append(currentPlace)

# %%
reg_prices == reg_prices_old
# Out:
# True
