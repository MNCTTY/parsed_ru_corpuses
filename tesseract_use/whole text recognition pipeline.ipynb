# %%
from PIL import Image 
import pytesseract 
import sys 
from pdf2image import convert_from_path 
import os 
import glob

# %%
path = 'Сематические Алгоритмы'
all_pdfs = glob.glob(path + '/**/*.pdf')
len(all_pdfs)

#создать общую папку для сканов
output_dir = path+'_jpged'
try:
    os.mkdir(output_dir)
except FileExistsError:
    print('done')
# Out:
# done

# %%
# %%time
for pdf in all_pdfs:
    foldername = '_'.join('.'.join(pdf.split('/')[-1].split('.')[:-1]).split(' '))
    pages = convert_from_path(pdf, 500) 
    image_counter = 1
    try:
        os.mkdir(output_dir + '/' + foldername)
    except FileExistsError:
        print('nah')
    for page in pages: 
        filename = output_dir + '/' + foldername + '/page_'+str(image_counter)+'.jpg'
        page.save(filename, 'JPEG') 
        image_counter += 1
# Out:
# nah
# nah
# nah
# nah
# nah
# CPU times: user 51.6 s, sys: 7.44 s, total: 59 s
# Wall time: 1min 59s

# %%
all_dirs = glob.glob(output_dir + '/**')
all_dirs

texted_dir = path+'_texted'
try:
    os.mkdir(texted_dir)
except FileExistsError:
    print('done')
# Out:
# done

# %%
# %%time
for dir_ in all_dirs:
    print('\n' + dir_ + '\n')
    files = glob.glob(dir_ + '/*')
    texted_file = texted_dir + '/' + dir_.split('/')[-1] + "_texted.txt"
    f = open(texted_file, "a") 
    for file in files:
        text = str(((pytesseract.image_to_string(Image.open(file), lang="rus+eng"))))
        #text = text.replace('\n', '')
        f.write(text)
    f.close()
    print(files)
# Out:
# Сематические Алгоритмы_jpged/Исх._№_5052_от_31.01.2020_г._вАХТА_ДО_90_ДНЕЙ
#
# ['Сематические Алгоритмы_jpged/Исх._№_5052_от_31.01.2020_г._вАХТА_ДО_90_ДНЕЙ/page_1.jpg']
#
# Сематические Алгоритмы_jpged/14-05-8736_от_05.08.19_о_Согласовании_Субподрядчика
#
# ['Сематические Алгоритмы_jpged/14-05-8736_от_05.08.19_о_Согласовании_Субподрядчика/page_1.jpg']
#
# Сематические Алгоритмы_jpged/15-02-5022_от_30.04.2019
#
# ['Сематические Алгоритмы_jpged/15-02-5022_от_30.04.2019/page_1.jpg']
#
# Сематические Алгоритмы_jpged/2_Протокол_УстанСовещания_КХМ_24.07.2019_ВСЕМИ_ПОДПИСАН
#
# ['Сематические Алгоритмы_jpged/2_Протокол_УстанСовещания_КХМ_24.07.2019_ВСЕМИ_ПОДПИСАН/page_2.jpg', 'Сематические Алгоритмы_jpged/2_Протокол_УстанСовещания_КХМ_24.07.2019_ВСЕМИ_ПОДПИСАН/page_3.jpg', 'Сематические Алгоритмы_jpged/2_Протокол_УстанСовещания_КХМ_24.07.2019_ВСЕМИ_ПОДПИСАН/page_1.jpg', 'Сематические Алгоритмы_jpged/2_Протокол_УстанСовещания_КХМ_24.07.2019_ВСЕМИ_ПОДПИСАН/page_4.jpg']
#
# Сематические Алгоритмы_jpged/1_Акт_пп_участка_№1
#
# ['Сематические Алгоритмы_jpged/1_Акт_пп_участка_№1/page_2.jpg', 'Сематические Алгоритмы_jpged/1_Акт_пп_участка_№1/page_3.jpg', 'Сематические Алгоритмы_jpged/1_Акт_пп_участка_№1/page_1.jpg']
# ['Сематические Алгоритмы_jpged/2_Акт_пп_участка_№3/page_2.jpg', 'Сематические Алгоритмы_jpged/2_Акт_пп_участка_№3/page_3.jpg', 'Сематические Алгоритмы_jpged/2_Акт_пп_участка_№3/page_1.jpg']
#
# Сематические Алгоритмы_jpged/1_Протокол_предуст_совещ_КХМ_28.05.2019_ИТОГ
#
# ['Сематические Алгоритмы_jpged/1_Протокол_предуст_совещ_КХМ_28.05.2019_ИТОГ/page_2.jpg', 'Сематические Алгоритмы_jpged/1_Протокол_предуст_совещ_КХМ_28.05.2019_ИТОГ/page_3.jpg', 'Сематические Алгоритмы_jpged/1_Протокол_предуст_совещ_КХМ_28.05.2019_ИТОГ/page_1.jpg', 'Сематические Алгоритмы_jpged/1_Протокол_предуст_совещ_КХМ_28.05.2019_ИТОГ/page_4.jpg']
#
# Сематические Алгоритмы_jpged/Письмо_№_Ц-640-4_от_16.04.2019
#
# ['Сематические Алгоритмы_jpged/Письмо_№_Ц-640-4_от_16.04.2019/page_2.jpg', 'Сематические Алгоритмы_jpged/Письмо_№_Ц-640-4_от_16.04.2019/page_3.jpg', 'Сематические Алгоритмы_jpged/Письмо_№_Ц-640-4_от_16.04.2019/page_1.jpg']
#
# Сематические Алгоритмы_jpged/исх._4223_от_18.07.2019_участники_Установочного_Совещания
#
# ['Сематические Алгоритмы_jpged/исх._4223_от_18.07.2019_участники_Установочного_Совещания/page_1.jpg']
#
# Сематические Алгоритмы_jpged/!!Аккредитованные_МО
#
# ['Сематические Алгоритмы_jpged/!!Аккредитованные_МО/page_2.jpg', 'Сематические Алгоритмы_jpged/!!Аккредитованные_МО/page_1.jpg']
#
# Сематические Алгоритмы_jpged/накладная_на_передачу_19.06.2019_06_55_09
#
# ['Сематические Алгоритмы_jpged/накладная_на_передачу_19.06.2019_06_55_09/page_2.jpg', 'Сематические Алгоритмы_jpged/накладная_на_передачу_19.06.2019_06_55_09/page_1.jpg']
#
# Сематические Алгоритмы_jpged/Исх_5005_от_14.01.2020_О_переносе_проактивных_на_2020
#
# ['Сематические Алгоритмы_jpged/Исх_5005_от_14.01.2020_О_переносе_проактивных_на_2020/page_2.jpg', 'Сематические Алгоритмы_jpged/Исх_5005_от_14.01.2020_О_переносе_проактивных_на_2020/page_1.jpg']
#
# Сематические Алгоритмы_jpged/8154_от_22.07.2019г._на_КХМ_о_проведении_Hazid
#
# ['Сематические Алгоритмы_jpged/8154_от_22.07.2019г._на_КХМ_о_проведении_Hazid/page_1.jpg']
#
# Сематические Алгоритмы_jpged/14_000134_от_22.01.2020_О_сроках_реализации_мероприятий_ПУД
#
# ['Сематические Алгоритмы_jpged/14_000134_от_22.01.2020_О_сроках_реализации_мероприятий_ПУД/page_1.jpg']
# CPU times: user 1min 17s, sys: 2.03 s, total: 1min 19s
# Wall time: 9min 16s

# %% [markdown]
# ## Trouble
#
# - Очень часто слова оказываются склеенными. Надо найти метод, который будет расклеивать их
#
#     ? может быть оставить это разметчикам?
#
#
# - Шапки вообще жесткие, просто поток слов, но нужны ли они?
